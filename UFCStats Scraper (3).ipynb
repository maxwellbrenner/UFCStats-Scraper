# %%
# Updated as of 10/4/2024 -- Functional
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import csv


# Define headers for the HTTP request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36'
}


def get_page_content(url):
    """
    Retrieve and parse HTML content from a specified URL using a user-defined number of retries.
    Returns a BeautifulSoup object if successful, otherwise None.

    Parameters:
    - url (str): The URL from which to fetch content.

    Returns:
    - BeautifulSoup: Parsed HTML of the page, or None if the request fails after retries.
    """
    try:
        response = requests.get(url, headers=headers)
        if response.status_code == 200:
            return BeautifulSoup(response.content, 'html.parser')
        else:
            print(f"Failed to retrieve the page. Status code: {response.status_code}")
    except requests.RequestException as e:
        print(f"Request failed: {e}")

    print("All attempts failed. Returning None.")
    return None


def extract_event_info(event_element):
    """
    Extracts basic information for a given event element including name, link, date, and location.
    
    Parameters:
    - event_element (bs4.element.Tag): The BeautifulSoup tag for the event.

    Returns:
    - dict: A dictionary containing event name, link, formatted date, location, and an empty list for fights.
    """
    event_name = event_element.text.strip()
    event_link = event_element['href']
    
    # Extract date and location information
    event_date_str = event_element.find_next('span', class_='b-statistics__date').text.strip()
    event_location_str = event_element.find_next('td', class_='b-statistics__table-col b-statistics__table-col_style_big-top-padding').text.strip()
    
    # Format the date as datetime object
    formatted_date = parse_date(event_date_str)
    
    # Create the event info dictionary
    event_info = {
        'name': event_name,
        'link': event_link,
        'date': formatted_date,
        'location': event_location_str,
        'fights': []  # Empty list to store fight information
    }
    
    # Retrieve event page content
    event_soup = get_page_content(event_info['link'])
    
    return event_info, event_soup


def parse_date(date_str):
    """
    Convert a date string into a datetime object, unless it is 'N/A'.

    Parameters:
    - date_str (str): The date string to convert.

    Returns:
    - datetime or None: The datetime object or None if input is 'N/A'.
    """
    if date_str != 'N/A':
        return datetime.strptime(date_str, '%B %d, %Y')
    else:
        return None
    

def extract_fight_info(fight_row):
    """
    Extracts information about a specific fight, including fighter details, fight link, winner, and method of victory.
    
    Parameters:
    - fight_row (bs4.element.Tag): The BeautifulSoup tag containing the row with fight details.

    Returns:
    - dict: A dictionary containing the fight link, winner, method of victory, and fighter details.
    """
    # Extract fighter information
    fighter_a, fighter_b = extract_fighter_info(fight_row)
    
    # Check for fight link and winner determination
    fight_link, winner, method_of_victory = get_fight_link_and_winner(fight_row)
    
    return {
        'fight_link': fight_link,
        'winner': winner,
        'method_of_victory': method_of_victory,
        'fighter_a': fighter_a,
        'fighter_b': fighter_b
    }


def extract_fighter_info(fighter_row):
    """
    Extracts and returns basic information about two fighters from a table row.

    Parameters:
    - fighter_row (bs4.element.Tag): BeautifulSoup tag containing the row with fighter data.

    Returns:
    - tuple: Two dictionaries containing fighter names, their respective links, and empty rounds info.
    """
    fighters = [fighter.text.strip() for fighter in fighter_row.find_all('a', class_='b-link b-link_style_black')]
    fighter_links = [fighter['href'] for fighter in fighter_row.find_all('a', class_='b-link b-link_style_black')]
    
    return ({'name': fighters[0], 'link': fighter_links[0], 'rounds_a': []}, {'name': fighters[1], 'link': fighter_links[1], 'rounds_b': []})


def get_fight_link_and_winner(fight_row):
    """
    Determines the fight link and the winner based on the table row information.
    
    Parameters:
    - fight_row (bs4.element.Tag): BeautifulSoup tag containing the row with fight details.

    Returns:
    - tuple: (fight_link, winner, method_of_victory)
    """
    primary_fight_link_element = fight_row.find('a', class_='b-flag b-flag_style_green')

    if primary_fight_link_element:
        fight_link = primary_fight_link_element['href']
        winner_element = fight_row.find('a', class_='b-link b-link_style_black')
        winner = winner_element.text.strip() if winner_element else 'N/A'  # Check if a winner is declared
        method_of_victory_element = fight_row.find('i', style='font-style: normal')
        method_of_victory = method_of_victory_element.text.strip() if method_of_victory_element else 'TBD'

        # Check for a draw if there is a decision but no winner
        if 'Decision' in method_of_victory and winner == 'N/A':
            winner = 'Draw'

    else:
        # Check for No Contest case first
        alternative_fight_link_element = fight_row.find('a', class_='b-flag b-flag_style_bordered')
        fight_link = alternative_fight_link_element['href'] if alternative_fight_link_element else 'N/A'

        # If no fight link is found, it's a No Contest
        if fight_link == 'N/A':
            winner = 'NC'
            method_of_victory = 'NC'
        else:
            # If there's no winner but not a draw or no contest, keep winner as 'N/A'
            winner = 'N/A'
            method_of_victory = 'TBD'

    return fight_link, winner, method_of_victory


def scrape_fight_info(fight_info):
    """
    Retrieves detailed fight information including rounds and results from the fight page, 
    then updates the fight_info dictionary.

    Parameters:
    - fight_info (dict): Dictionary containing basic information about the fight and links.
    """
    fight_url = fight_info['fight_link']
    fight_soup = get_page_content(fight_url)

    if not fight_soup:
        print(f"Failed to retrieve the fight page for {fight_info['fighter_a']['name']} vs {fight_info['fighter_b']['name']}. Skipping...")
        return

    weight_class_element = fight_soup.find('i', class_='b-fight-details__fight-title')
    weight_class = weight_class_element.text.strip() if weight_class_element else 'N/A'

    # Updating fight_info with the obtained data
    fight_info.update({
        'weight_class': weight_class,
        'title_fight': 'title' in weight_class.lower(),
        'gender': 'women' if 'women' in weight_class.lower() else 'men',
        'method_of_victory': fight_info.get('method_of_victory', 'N/A'),
        'round_of_victory': 'N/A',
        'time_in_ROV': 'N/A',
        'time_format': 'N/A',
        'referee': 'N/A'
    })

    if fight_info['method_of_victory'] != 'NC':  # Only update if not a 'No Contest'
        extract_victory_and_round_data(fight_soup, fight_info)

    # Parsing round information and strikes data
    rows_fighter_data = fight_soup.select('.b-fight-details__section.js-fight-section')[2].find('table', class_='b-fight-details__table').select('tbody > tr.b-fight-details__table-row')
    rows_strikes_data = fight_soup.select('.b-fight-details__section.js-fight-section')[4].find('table', class_='b-fight-details__table').select('tbody > tr.b-fight-details__table-row')

    for i, (row_fighter_data, row_strikes_data) in enumerate(zip(rows_fighter_data, rows_strikes_data), start=1):
        extract_round_data(row_fighter_data, row_strikes_data, fight_info['fighter_a']['name'], fight_info['fighter_b']['name'], fight_info)

    print(f"\nFight Summary for {fight_info['fighter_a']['name']} vs {fight_info['fighter_b']['name']}:")
    print(f"Winner: {fight_info['winner']}")  # Ensures 'NC' is printed for No Contests
    print(f"Method of Victory: {fight_info['method_of_victory']}")
    print(f"Round of Victory: {fight_info['round_of_victory']}")
    print(f"Time of Victory: {fight_info['time_in_ROV']}")
    print(f"Time Format: {fight_info['time_format']}")
    print(f"Weight Class: {fight_info['weight_class']}")
    print(f"Referee: {fight_info['referee']}")
    print(f"Title Fight: {fight_info['title_fight']}")
    print(f"Gender: {fight_info['gender']}")
    print(f"Fight Link: {fight_info['fight_link']}")

    # Print rounds information for both fighters
    print("\nRounds Information:")
    for i, round_data in enumerate(fight_info['fighter_a']['rounds_a'], start=1):
        print(f"\nRound {i}:")
        print(f"Fighter A: {round_data}")
        print(f"\nFighter B: {fight_info['fighter_b']['rounds_b'][i-1]}")

        
def extract_victory_and_round_data(fight_soup, fight_info):
    """
    Extracts method of victory, round, time of victory, time format, and referee data from fight page.

    Parameters:
    - fight_soup (BeautifulSoup): Parsed HTML of the fight page.
    - fight_info (dict): Dictionary containing fight information to update.
    """
    method_victory_element = fight_soup.find('i', style='font-style: normal')
    if method_victory_element:
        fight_info['method_of_victory'] = method_victory_element.text.strip()

    round_element = fight_soup.find('i', class_='b-fight-details__text-item')
    if round_element and round_element.contents:
        fight_info['round_of_victory'] = round_element.contents[-1].strip()

        time_element = round_element.find_next('i', class_='b-fight-details__text-item')
        if time_element and time_element.contents:
            fight_info['time_in_ROV'] = time_element.contents[-1].strip()

            format_element = time_element.find_next('i', class_='b-fight-details__text-item')
            if format_element and format_element.contents:
                fight_info['time_format'] = format_element.contents[-1].strip()

                referee_element = format_element.find_next('span', class_='')
                if referee_element:
                    fight_info['referee'] = referee_element.text.strip()

                    
def extract_round_data(row_fighter_data, row_strikes_data, fighter_a_name, fighter_b_name, fight_info):
    """
    Extracts round-by-round data for both fighters and updates the fight_info dictionary.

    Parameters:
    - row_fighter_data (bs4.element.Tag): The row containing fighter-specific data.
    - row_strikes_data (bs4.element.Tag): The row containing strike-specific data.
    - fighter_a_name (str): Name of Fighter A.
    - fighter_b_name (str): Name of Fighter B.
    - fight_info (dict): The dictionary containing fight information to update.
    """
    fighter_one_data = extract_fighter_data(row_fighter_data, 0)
    fighter_two_data = extract_fighter_data(row_fighter_data, 1)
    fighter_one_strikes_data = extract_strikes_data(row_strikes_data, 0)
    fighter_two_strikes_data = extract_strikes_data(row_strikes_data, 1)

    fighter_one_data.update(fighter_one_strikes_data)
    fighter_two_data.update(fighter_two_strikes_data)

    if fighter_one_data['name'] == fighter_a_name:
        fight_info['fighter_a']['rounds_a'].append(fighter_one_data)
        fight_info['fighter_b']['rounds_b'].append(fighter_two_data)
    else:
        fight_info['fighter_a']['rounds_a'].append(fighter_two_data)
        fight_info['fighter_b']['rounds_b'].append(fighter_one_data)

        
def extract_fighter_data(row, index):
    """
    Extracts and returns detailed statistics of a fighter from a specific row in the table.

    Parameters:
    - row (bs4.element.Tag): The row from which to extract data.
    - index (int): Index to specify the fighter (0 for the first, 1 for the second).

    Returns:
    - dict: Dictionary containing various statistics for the fighter.
    """
    fighter_name_element = row.select('.b-fight-details__table-col.l-page_align_left a')
    fighter_name = fighter_name_element[index].text.strip() if fighter_name_element else 'N/A'

    knockdowns_element = row.select(f'.b-fight-details__table-col:nth-of-type(2) p')
    knockdowns = knockdowns_element[index].text.strip() if knockdowns_element else 'N/A'

    sig_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(3) p')
    sig_strikes = sig_strikes_element[index].text.strip() if sig_strikes_element else 'N/A'

    total_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(5) p')
    total_strikes = total_strikes_element[index].text.strip() if total_strikes_element else 'N/A'

    takedowns_element = row.select(f'.b-fight-details__table-col:nth-of-type(6) p')
    takedowns = takedowns_element[index].text.strip() if takedowns_element else 'N/A'

    sub_attempts_element = row.select(f'.b-fight-details__table-col:nth-of-type(8) p')
    sub_attempts = sub_attempts_element[index].text.strip() if sub_attempts_element else 'N/A'

    reversals_element = row.select(f'.b-fight-details__table-col:nth-of-type(9) p')
    reversals = reversals_element[index].text.strip() if reversals_element else 'N/A'

    control_time_element = row.select(f'.b-fight-details__table-col:nth-of-type(10) p')
    control_time = control_time_element[index].text.strip() if control_time_element else 'N/A'

    return {
        'name': fighter_name,
        'knockdowns': knockdowns,
        'sig_strikes': sig_strikes,
        'total_strikes': total_strikes,
        'takedowns': takedowns,
        'sub_attempts': sub_attempts,
        'reversals': reversals,
        'control_time': control_time,
    }


def extract_strikes_data(row, index):
    """
    Extracts detailed strikes data for a fighter from a specified row of the table.

    Parameters:
    - row (bs4.element.Tag): The BeautifulSoup tag of the row from which to extract data.
    - index (int): The index indicating which fighter's data to extract (0 for fighter_a, 1 for fighter_b).

    Returns:
    - dict: Dictionary containing various types of strikes information.
    """
    head_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(4) p')
    head_strikes = head_strikes_element[index].text.strip() if head_strikes_element else 'N/A'

    body_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(5) p')
    body_strikes = body_strikes_element[index].text.strip() if body_strikes_element else 'N/A'

    leg_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(6) p')
    leg_strikes = leg_strikes_element[index].text.strip() if leg_strikes_element else 'N/A'

    distance_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(7) p')
    distance_strikes = distance_strikes_element[index].text.strip() if distance_strikes_element else 'N/A'

    clinch_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(8) p')
    clinch_strikes = clinch_strikes_element[index].text.strip() if clinch_strikes_element else 'N/A'

    ground_strikes_element = row.select(f'.b-fight-details__table-col:nth-of-type(9) p')
    ground_strikes = ground_strikes_element[index].text.strip() if ground_strikes_element else 'N/A'

    return {
        'head_strikes': head_strikes,
        'body_strikes': body_strikes,
        'leg_strikes': leg_strikes,
        'distance_strikes': distance_strikes,
        'clinch_strikes': clinch_strikes,
        'ground_strikes': ground_strikes,
    }


def scrape_fighter_info(fighter_info):
    """
    Scrapes and stores individual fighter details such as height, reach, and date of birth from the fighter's page.

    Parameters:
    - fighter_info (dict): Dictionary containing the fighter's name and link.
    """
    fighter_url = fighter_info['link']
    fighter_soup = get_page_content(fighter_url)

    if not fighter_soup:
        print(f"Failed to retrieve the fighter page for {fighter_info['name']}. Skipping...")
        return

    details_list = fighter_soup.find('ul', class_='b-list__box-list')
    details_items = details_list.find_all('li', class_='b-list__box-list-item')

    height_info = None
    reach_info = None
    dob_info = None

    for item in details_items:
        title = item.find('i', class_='b-list__box-item-title')
        if title:
            if 'Height' in title.text:
                height_info = item.contents[-1].strip()
            elif 'Reach' in title.text:
                reach_info = item.contents[-1].strip()
            elif 'DOB' in title.text:
                dob_info = item.contents[-1].strip()

    if height_info:
        fighter_info['height'] = {'feet_inches': height_info, 'inches': convert_to_inches(height_info)['inches']}
    else:
        fighter_info['height'] = {'feet_inches': 'N/A', 'inches': 'N/A'}

    if reach_info:
        fighter_info['reach'] = reach_info
    else:
        fighter_info['reach'] = 'N/A'

    if dob_info:
        fighter_info['dob'] = convert_to_numerical_date(dob_info)
    else:
        fighter_info['dob'] = None

    print(f"\nFighter Info for {fighter_info['name']}:")
    print(f"Height: {fighter_info['height']['feet_inches']}")
    print(f"Reach: {fighter_info['reach']}")
    print(f"Date of Birth: {fighter_info['dob']}")
    print(f"Fighter Link: {fighter_info['link']}")

    
def convert_to_inches(height_info):
    """
    Convert a height string from the format "feet'inches"" into inches only.

    Parameters:
    - height_info (str): The height string, e.g., "6'0"".

    Returns:
    - dict: Dictionary containing original and converted height information.
    """
    try:
        feet, inches = map(int, height_info.replace('"', '').split("'"))
        total_inches = feet * 12 + inches
        return {'feet_inches': f"{feet}' {inches}\"", 'inches': total_inches}
    except ValueError:
        return {'feet_inches': 'N/A', 'inches': 'N/A'}

    
def convert_to_numerical_date(date_str):
    """
    Convert a date string into a datetime object.

    Parameters:
    - date_str (str): The date string to convert, in the format '%b %d, %Y'.

    Returns:
    - datetime or None: The datetime object or None if conversion fails.
    """
    try:
        return datetime.strptime(date_str, '%b %d, %Y')
    except ValueError:
        return None


    
def write_to_csv(events_list):
    """
    Writes collected event data to a CSV file, including detailed round statistics for each fight.

    Parameters:
    - events_list (list): List of dictionaries, each representing an event and its associated fight data.
    """
    headers = [
        "event_name", "event_date", "event_location", "winner",
        "fighter_a_name", "fighter_b_name", "weightclass", "method_of_victory",
        "round_of_victory", "time_of_victory", "time_format", "referee",
        "title_fight", "gender", "fight_link", "fighter_a_height", "fighter_a_reach", "fighter_a_dob",
        "fighter_b_height", "fighter_b_reach", "fighter_b_dob"
    ]
    
    # Extend headers with round details for both fighters across five rounds
    rounds = 5
    for round_num in range(1, rounds + 1):
        for side in ['a', 'b']:
            prefix = f'rnd_{round_num}_{side}'
            headers.extend([
                f"{prefix}_knockdowns", f"{prefix}_sig_strikes", f"{prefix}_total_strikes",
                f"{prefix}_takedowns", f"{prefix}_sub_attemps", f"{prefix}_reversals",
                f"{prefix}_control_time", f"{prefix}_head_strikes", f"{prefix}_body_strikes",
                f"{prefix}_leg_strikes", f"{prefix}_distance_strikes", f"{prefix}_clinch_strikes",
                f"{prefix}_ground_strikes"
            ])

    with open('event_masterlist.csv', 'w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(headers)

        for event in events_list:
            for fight in event['fights']:
                row = [
                    event['name'], event['date'], event['location'], fight['winner'],
                    fight['fighter_a']['name'], fight['fighter_b']['name'],
                    fight['weight_class'], fight['method_of_victory'],
                    fight['round_of_victory'], fight['time_in_ROV'], fight['time_format'],
                    fight['referee'], fight['title_fight'], fight['gender'],
                    fight['fight_link'], fight['fighter_a'].get('height', {}).get('inches', 'NaN'),
                    fight['fighter_a'].get('reach', 'NaN'), fight['fighter_a'].get('dob', 'NaN'),
                    fight['fighter_b'].get('height', {}).get('inches', 'NaN'),
                    fight['fighter_b'].get('reach', 'NaN'),
                    fight['fighter_b'].get('dob', 'NaN')
                ]
                
                # Adding round details for each fighter
                for round_num in range(1, rounds + 1):
                    for side in ['a', 'b']:
                        round_data = fight.get(f'fighter_{side}').get(f'rounds_{side}', [])
                        if len(round_data) >= round_num:
                            round_stats = round_data[round_num - 1]
                            row.extend([
                                round_stats.get('knockdowns', 'NaN'),
                                round_stats.get('sig_strikes', 'NaN'),
                                round_stats.get('total_strikes', 'NaN'),
                                round_stats.get('takedowns', 'NaN'),
                                round_stats.get('sub_attempts', 'NaN'),
                                round_stats.get('reversals', 'NaN'),
                                round_stats.get('control_time', 'NaN'),
                                round_stats.get('head_strikes', 'NaN'),
                                round_stats.get('body_strikes', 'NaN'),
                                round_stats.get('leg_strikes', 'NaN'),
                                round_stats.get('distance_strikes', 'NaN'),
                                round_stats.get('clinch_strikes', 'NaN'),
                                round_stats.get('ground_strikes', 'NaN')
                            ])
                        else:
                            row.extend(['NaN'] * 13)  # Add NaN for all round stats if round data is missing

                writer.writerow(row)

                
def main():
    """
    Main function to orchestrate the web scraping process, including retrieving event data,
    scraping fight details and individual fighter stats, and finally writing all data to a CSV file.
    
    Returns:
    - list: List of dictionaries with detailed event and fight information (used for writing to CSV).
    """
    try:
        # URL of the main page listing all completed events
        url = 'http://www.ufcstats.com/statistics/events/completed?page=all'
        soup = get_page_content(url)

        # Check if the main page content was successfully retrieved
        if soup:
            event_elements = soup.find_all('a', class_='b-link b-link_style_black')
            events_list = []

            # Iterate over each event link found on the main page
            for event_element in event_elements:
                event_info, event_soup = extract_event_info(event_element)

                # Check if the event page content was successfully retrieved
                if event_soup:
                    fight_rows = event_soup.find_all('tr', class_='b-fight-details__table-row')[1:]  # Skip the header row which contains a future event

                    # Iterate over fight rows and extract fight information
                    for fight_row in fight_rows:
                        fight_info = extract_fight_info(fight_row)
                        event_info['fights'].append(fight_info)

                    events_list.append(event_info)

            # Process each event and associated fights to scrape detailed information
            for event_info in events_list:
                print(f"\nEvent: {event_info['name']}")
                print(f"Event Link: {event_info['link']}")
                print(f"Date: {event_info['date']}")
                print(f"Location: {event_info['location']}")

                for fight_info in event_info['fights']:
                    scrape_fight_info(fight_info)
                    scrape_fighter_info(fight_info['fighter_a'])
                    scrape_fighter_info(fight_info['fighter_b'])

        # Return the populated event list, useful for unit testing or further processing
        return events_list

    except Exception as e:
        print(f"An error occurred: {e}")
    finally:
        # Always attempt to save data to CSV, even if an error occurs
        if events_list:
            print("Saving data to CSV due to an error or normal completion.")
            write_to_csv(events_list)

            
if __name__ == "__main__":
    # Script entry point, calls the main function to start the process
    events_list = main()
    write_to_csv(events_list)  # Ensure data is saved at the end of processing

    
# Small clerical note:
# I'm not sure why, but there is a delay in start time. You must run the cell and then wait, sometimes upwards
# of 5 minutes, for the scraping to begin. I couldn't figure out how to fix this, but it does
# work. I promise. You just have to be patient. I apologize for any inconvenience.
# Out:
# Fight Summary for Ilia Topuria vs Max Holloway:
# Winner: Ilia Topuria
# Method of Victory: KO/TKO
# Round of Victory: 3
# Time of Victory: 1:34
# Time Format: 5 Rnd (5-5-5-5-5)
# Weight Class: UFC Featherweight Title Bout
# Referee: Marc Goddard
# Title Fight: True
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/ebf7cea27b83c432
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Ilia Topuria', 'knockdowns': '0', 'sig_strikes': '22 of 47', 'total_strikes': '24 of 49', 'takedowns': '2 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:41', 'head_strikes': '13 of 38', 'body_strikes': '3 of 3', 'leg_strikes': '6 of 6', 'distance_strikes': '22 of 47', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Max Holloway', 'knockdowns': '0', 'sig_strikes': '30 of 75', 'total_strikes': '35 of 80', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '17 of 56', 'body_strikes': '7 of 12', 'leg_strikes': '6 of 7', 'distance_strikes': '30 of 75', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Ilia Topuria', 'knockdowns': '0', 'sig_strikes': '32 of 62', 'total_strikes': '32 of 62', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '20 of 47', 'body_strikes': '5 of 7', 'leg_strikes': '7 of 8', 'distance_strikes': '32 of 62', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Max Holloway', 'knockdowns': '0', 'sig_strikes': '35 of 102', 'total_strikes': '35 of 102', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '23 of 79', 'body_strikes': '3 of 13', 'leg_strikes': '9 of 10', 'distance_strikes': '35 of 102', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Ilia Topuria', 'knockdowns': '1', 'sig_strikes': '21 of 35', 'total_strikes': '22 of 36', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:04', 'head_strikes': '16 of 29', 'body_strikes': '3 of 4', 'leg_strikes': '2 of 2', 'distance_strikes': '17 of 31', 'clinch_strikes': '0 of 0', 'ground_strikes': '4 of 4'}
#
# Fighter B: {'name': 'Max Holloway', 'knockdowns': '0', 'sig_strikes': '14 of 27', 'total_strikes': '14 of 27', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '7 of 16', 'body_strikes': '3 of 5', 'leg_strikes': '4 of 6', 'distance_strikes': '14 of 27', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Ilia Topuria:
# Height: 5' 7"
# Reach: 69"
# Date of Birth: 1997-01-21 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/54f64b5e283b0ce7
#
# Fighter Info for Max Holloway:
# Height: 5' 11"
# Reach: 69"
# Date of Birth: 1991-12-04 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/150ff4cc642270b9
#
# Fight Summary for Khamzat Chimaev vs Robert Whittaker:
# Winner: Khamzat Chimaev
# Method of Victory: Submission
# Round of Victory: 1
# Time of Victory: 3:34
# Time Format: 5 Rnd (5-5-5-5-5)
# Weight Class: Middleweight Bout
# Referee: Jason Herzog
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/b8bf186f884678ea
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Khamzat Chimaev', 'knockdowns': '0', 'sig_strikes': '3 of 4', 'total_strikes': '25 of 31', 'takedowns': '2 of 4', 'sub_attempts': '1', 'reversals': '0', 'control_time': '3:20', 'head_strikes': '2 of 3', 'body_strikes': '1 of 1', 'leg_strikes': '0 of 0', 'distance_strikes': '0 of 1', 'clinch_strikes': '0 of 0', 'ground_strikes': '3 of 3'}
#
# Fighter B: {'name': 'Robert Whittaker', 'knockdowns': '0', 'sig_strikes': '2 of 2', 'total_strikes': '2 of 2', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '0 of 0', 'body_strikes': '0 of 0', 'leg_strikes': '2 of 2', 'distance_strikes': '2 of 2', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Khamzat Chimaev:
# Height: 6' 2"
# Reach: 75"
# Date of Birth: 1994-05-01 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/767755fd74662dbf
#
# Fighter Info for Robert Whittaker:
# Height: 6' 0"
# Reach: 73"
# Date of Birth: 1990-12-20 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/e1147d3d2dabe1ce
#
# Fight Summary for Magomed Ankalaev vs Aleksandar Rakic:
# Winner: Magomed Ankalaev
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Light Heavyweight Bout
# Referee: Vitor Ribeiro
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/b09f54654b0f95f5
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Magomed Ankalaev', 'knockdowns': '0', 'sig_strikes': '19 of 34', 'total_strikes': '19 of 34', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '7 of 19', 'body_strikes': '8 of 11', 'leg_strikes': '4 of 4', 'distance_strikes': '19 of 34', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Aleksandar Rakic', 'knockdowns': '0', 'sig_strikes': '22 of 45', 'total_strikes': '22 of 45', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '4 of 24', 'body_strikes': '3 of 4', 'leg_strikes': '15 of 17', 'distance_strikes': '22 of 45', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Magomed Ankalaev', 'knockdowns': '0', 'sig_strikes': '23 of 50', 'total_strikes': '24 of 52', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:13', 'head_strikes': '8 of 33', 'body_strikes': '7 of 9', 'leg_strikes': '8 of 8', 'distance_strikes': '23 of 49', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Aleksandar Rakic', 'knockdowns': '0', 'sig_strikes': '19 of 43', 'total_strikes': '20 of 44', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:06', 'head_strikes': '3 of 24', 'body_strikes': '3 of 5', 'leg_strikes': '13 of 14', 'distance_strikes': '18 of 41', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Magomed Ankalaev', 'knockdowns': '0', 'sig_strikes': '13 of 30', 'total_strikes': '32 of 56', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:18', 'head_strikes': '5 of 20', 'body_strikes': '7 of 9', 'leg_strikes': '1 of 1', 'distance_strikes': '8 of 22', 'clinch_strikes': '5 of 8', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Aleksandar Rakic', 'knockdowns': '0', 'sig_strikes': '12 of 29', 'total_strikes': '17 of 34', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:54', 'head_strikes': '3 of 17', 'body_strikes': '3 of 3', 'leg_strikes': '6 of 9', 'distance_strikes': '10 of 25', 'clinch_strikes': '2 of 4', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Magomed Ankalaev:
# Height: 6' 3"
# Reach: 75"
# Date of Birth: 1992-06-02 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/d802174b0c0c1f4e
#
# Fighter Info for Aleksandar Rakic:
# Height: 6' 4"
# Reach: 78"
# Date of Birth: 1992-02-06 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/333b9e5c723ac873
#
# Fight Summary for Lerone Murphy vs Dan Ige:
# Winner: Lerone Murphy
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Featherweight Bout
# Referee: Mark Smith
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/cc11a0762f246fa4
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Lerone Murphy', 'knockdowns': '0', 'sig_strikes': '17 of 32', 'total_strikes': '18 of 33', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:22', 'head_strikes': '11 of 23', 'body_strikes': '4 of 5', 'leg_strikes': '2 of 4', 'distance_strikes': '14 of 28', 'clinch_strikes': '3 of 4', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Dan Ige', 'knockdowns': '1', 'sig_strikes': '32 of 60', 'total_strikes': '32 of 61', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '1', 'control_time': '1:30', 'head_strikes': '27 of 53', 'body_strikes': '2 of 4', 'leg_strikes': '3 of 3', 'distance_strikes': '19 of 39', 'clinch_strikes': '5 of 11', 'ground_strikes': '8 of 10'}
#
# Round 2:
# Fighter A: {'name': 'Lerone Murphy', 'knockdowns': '0', 'sig_strikes': '19 of 42', 'total_strikes': '36 of 61', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:57', 'head_strikes': '12 of 31', 'body_strikes': '6 of 10', 'leg_strikes': '1 of 1', 'distance_strikes': '16 of 36', 'clinch_strikes': '3 of 5', 'ground_strikes': '0 of 1'}
#
# Fighter B: {'name': 'Dan Ige', 'knockdowns': '0', 'sig_strikes': '11 of 29', 'total_strikes': '12 of 31', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '1', 'control_time': '0:43', 'head_strikes': '5 of 22', 'body_strikes': '3 of 4', 'leg_strikes': '3 of 3', 'distance_strikes': '10 of 28', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Lerone Murphy', 'knockdowns': '0', 'sig_strikes': '16 of 26', 'total_strikes': '24 of 39', 'takedowns': '1 of 3', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:58', 'head_strikes': '13 of 23', 'body_strikes': '2 of 2', 'leg_strikes': '1 of 1', 'distance_strikes': '7 of 16', 'clinch_strikes': '6 of 7', 'ground_strikes': '3 of 3'}
#
# Fighter B: {'name': 'Dan Ige', 'knockdowns': '0', 'sig_strikes': '3 of 17', 'total_strikes': '8 of 24', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:34', 'head_strikes': '3 of 17', 'body_strikes': '0 of 0', 'leg_strikes': '0 of 0', 'distance_strikes': '3 of 12', 'clinch_strikes': '0 of 4', 'ground_strikes': '0 of 1'}
#
# Fighter Info for Lerone Murphy:
# Height: 5' 9"
# Reach: 73"
# Date of Birth: 1991-07-22 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/396fe87b84ac2e1c
#
# Fighter Info for Dan Ige:
# Height: 5' 7"
# Reach: 71"
# Date of Birth: 1991-08-06 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/82a5152216251682
#
# Fight Summary for Shara Magomedov vs Armen Petrosyan:
# Winner: Shara Magomedov
# Method of Victory: KO/TKO
# Round of Victory: 2
# Time of Victory: 4:52
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Middleweight Bout
# Referee: Kerry Hatley
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/108434acbbd75d26
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Shara Magomedov', 'knockdowns': '0', 'sig_strikes': '33 of 49', 'total_strikes': '35 of 51', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '12 of 24', 'body_strikes': '13 of 14', 'leg_strikes': '8 of 11', 'distance_strikes': '31 of 47', 'clinch_strikes': '2 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Armen Petrosyan', 'knockdowns': '0', 'sig_strikes': '46 of 81', 'total_strikes': '46 of 81', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:08', 'head_strikes': '14 of 35', 'body_strikes': '5 of 7', 'leg_strikes': '27 of 39', 'distance_strikes': '44 of 79', 'clinch_strikes': '2 of 2', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Shara Magomedov', 'knockdowns': '1', 'sig_strikes': '32 of 57', 'total_strikes': '32 of 57', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:02', 'head_strikes': '12 of 29', 'body_strikes': '16 of 20', 'leg_strikes': '4 of 8', 'distance_strikes': '32 of 57', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Armen Petrosyan', 'knockdowns': '0', 'sig_strikes': '31 of 59', 'total_strikes': '31 of 60', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:13', 'head_strikes': '8 of 31', 'body_strikes': '5 of 7', 'leg_strikes': '18 of 21', 'distance_strikes': '31 of 59', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Shara Magomedov:
# Height: 6' 2"
# Reach: 73"
# Date of Birth: 1994-05-16 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/06734ca9d88dec3a
#
# Fighter Info for Armen Petrosyan:
# Height: 6' 3"
# Reach: 71"
# Date of Birth: 1990-11-03 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/369ea36e450ae62a
#
# Fight Summary for Ibo Aslan vs Rafael Cerqueira:
# Winner: Ibo Aslan
# Method of Victory: KO/TKO
# Round of Victory: 1
# Time of Victory: 0:51
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Light Heavyweight Bout
# Referee: Marc Goddard
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/781a2ea50f5ae68f
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Ibo Aslan', 'knockdowns': '0', 'sig_strikes': '28 of 36', 'total_strikes': '28 of 36', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '26 of 33', 'body_strikes': '2 of 2', 'leg_strikes': '0 of 1', 'distance_strikes': '28 of 36', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Rafael Cerqueira', 'knockdowns': '0', 'sig_strikes': '1 of 1', 'total_strikes': '1 of 1', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '0 of 0', 'body_strikes': '0 of 0', 'leg_strikes': '1 of 1', 'distance_strikes': '1 of 1', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Ibo Aslan:
# Height: 6' 3"
# Reach: 77"
# Date of Birth: 1996-04-23 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/6e8f1bcdda94ff45
#
# Fighter Info for Rafael Cerqueira:
# Height: 6' 3"
# Reach: 76"
# Date of Birth: 1990-03-15 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/09a4447655fd4b7b
#
# Fight Summary for Geoff Neal vs Rafael Dos Anjos:
# Winner: Geoff Neal
# Method of Victory: KO/TKO
# Round of Victory: 1
# Time of Victory: 1:30
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Welterweight Bout
# Referee: Mark Smith
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/1d65c141776949d6
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Geoff Neal', 'knockdowns': '1', 'sig_strikes': '18 of 30', 'total_strikes': '21 of 34', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:27', 'head_strikes': '12 of 24', 'body_strikes': '3 of 3', 'leg_strikes': '3 of 3', 'distance_strikes': '13 of 24', 'clinch_strikes': '0 of 0', 'ground_strikes': '5 of 6'}
#
# Fighter B: {'name': 'Rafael Dos Anjos', 'knockdowns': '0', 'sig_strikes': '4 of 13', 'total_strikes': '4 of 13', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '2 of 10', 'body_strikes': '1 of 1', 'leg_strikes': '1 of 2', 'distance_strikes': '4 of 13', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Geoff Neal:
# Height: 5' 11"
# Reach: 75"
# Date of Birth: 1990-08-28 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/b997be68943010fc
#
# Fighter Info for Rafael Dos Anjos:
# Height: 5' 8"
# Reach: 70"
# Date of Birth: 1984-10-26 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/6a2f7c151031653d
#
# Fight Summary for Mateusz Rebecki vs Myktybek Orolbai:
# Winner: Mateusz Rebecki
# Method of Victory: Decision - Split
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Catch Weight Bout
# Referee: Vitor Ribeiro
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/919e3c5cc6999cb3
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Mateusz Rebecki', 'knockdowns': '0', 'sig_strikes': '27 of 57', 'total_strikes': '27 of 57', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '15 of 43', 'body_strikes': '7 of 7', 'leg_strikes': '5 of 7', 'distance_strikes': '26 of 56', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Myktybek Orolbai', 'knockdowns': '0', 'sig_strikes': '22 of 51', 'total_strikes': '22 of 51', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '13 of 39', 'body_strikes': '2 of 4', 'leg_strikes': '7 of 8', 'distance_strikes': '22 of 51', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Mateusz Rebecki', 'knockdowns': '0', 'sig_strikes': '23 of 55', 'total_strikes': '24 of 56', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:15', 'head_strikes': '17 of 47', 'body_strikes': '3 of 4', 'leg_strikes': '3 of 4', 'distance_strikes': '22 of 54', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Myktybek Orolbai', 'knockdowns': '0', 'sig_strikes': '25 of 57', 'total_strikes': '28 of 61', 'takedowns': '1 of 4', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:44', 'head_strikes': '19 of 50', 'body_strikes': '4 of 5', 'leg_strikes': '2 of 2', 'distance_strikes': '25 of 56', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Mateusz Rebecki', 'knockdowns': '1', 'sig_strikes': '21 of 34', 'total_strikes': '42 of 61', 'takedowns': '3 of 3', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:09', 'head_strikes': '20 of 33', 'body_strikes': '0 of 0', 'leg_strikes': '1 of 1', 'distance_strikes': '6 of 16', 'clinch_strikes': '3 of 4', 'ground_strikes': '12 of 14'}
#
# Fighter B: {'name': 'Myktybek Orolbai', 'knockdowns': '0', 'sig_strikes': '14 of 27', 'total_strikes': '35 of 50', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '1', 'control_time': '1:21', 'head_strikes': '14 of 25', 'body_strikes': '0 of 2', 'leg_strikes': '0 of 0', 'distance_strikes': '13 of 26', 'clinch_strikes': '0 of 0', 'ground_strikes': '1 of 1'}
#
# Fighter Info for Mateusz Rebecki:
# Height: 5' 7"
# Reach: 66"
# Date of Birth: 1992-11-03 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/849c5d9979df5357
#
# Fighter Info for Myktybek Orolbai:
# Height: 5' 10"
# Reach: 74"
# Date of Birth: 1998-02-10 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/bf2c8e01b07d3eb1
#
# Fight Summary for Abus Magomedov vs Brunno Ferreira:
# Winner: Abus Magomedov
# Method of Victory: Submission
# Round of Victory: 3
# Time of Victory: 3:14
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Middleweight Bout
# Referee: Marc Goddard
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/af6eeea1cfe33240
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Abus Magomedov', 'knockdowns': '0', 'sig_strikes': '14 of 29', 'total_strikes': '14 of 29', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '4 of 17', 'body_strikes': '5 of 7', 'leg_strikes': '5 of 5', 'distance_strikes': '14 of 29', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Brunno Ferreira', 'knockdowns': '0', 'sig_strikes': '2 of 12', 'total_strikes': '2 of 12', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '0 of 8', 'body_strikes': '2 of 4', 'leg_strikes': '0 of 0', 'distance_strikes': '2 of 12', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Abus Magomedov', 'knockdowns': '0', 'sig_strikes': '8 of 23', 'total_strikes': '21 of 37', 'takedowns': '2 of 5', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:14', 'head_strikes': '3 of 18', 'body_strikes': '2 of 2', 'leg_strikes': '3 of 3', 'distance_strikes': '8 of 21', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 2'}
#
# Fighter B: {'name': 'Brunno Ferreira', 'knockdowns': '0', 'sig_strikes': '20 of 42', 'total_strikes': '22 of 47', 'takedowns': '0 of 0', 'sub_attempts': '1', 'reversals': '0', 'control_time': '0:06', 'head_strikes': '16 of 38', 'body_strikes': '4 of 4', 'leg_strikes': '0 of 0', 'distance_strikes': '18 of 37', 'clinch_strikes': '0 of 1', 'ground_strikes': '2 of 4'}
#
# Round 3:
# Fighter A: {'name': 'Abus Magomedov', 'knockdowns': '0', 'sig_strikes': '4 of 7', 'total_strikes': '10 of 15', 'takedowns': '2 of 3', 'sub_attempts': '1', 'reversals': '0', 'control_time': '1:22', 'head_strikes': '3 of 5', 'body_strikes': '1 of 2', 'leg_strikes': '0 of 0', 'distance_strikes': '4 of 7', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Brunno Ferreira', 'knockdowns': '0', 'sig_strikes': '7 of 17', 'total_strikes': '12 of 24', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '1', 'control_time': '0:07', 'head_strikes': '4 of 13', 'body_strikes': '3 of 4', 'leg_strikes': '0 of 0', 'distance_strikes': '6 of 16', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Abus Magomedov:
# Height: 6' 2"
# Reach: 78"
# Date of Birth: 1990-09-02 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/36b8f265bcd1b7a4
#
# Fighter Info for Brunno Ferreira:
# Height: 5' 10"
# Reach: 72"
# Date of Birth: 1992-11-04 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/1e719d4b676dc19a
#
# Fight Summary for Kennedy Nzechukwu vs Chris Barnett:
# Winner: Kennedy Nzechukwu
# Method of Victory: KO/TKO
# Round of Victory: 1
# Time of Victory: 4:27
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Heavyweight Bout
# Referee: Jason Herzog
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/df7928de73fc2fe8
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Kennedy Nzechukwu', 'knockdowns': '0', 'sig_strikes': '51 of 74', 'total_strikes': '51 of 74', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '28 of 50', 'body_strikes': '22 of 23', 'leg_strikes': '1 of 1', 'distance_strikes': '50 of 73', 'clinch_strikes': '0 of 0', 'ground_strikes': '1 of 1'}
#
# Fighter B: {'name': 'Chris Barnett', 'knockdowns': '0', 'sig_strikes': '12 of 34', 'total_strikes': '12 of 34', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '3 of 22', 'body_strikes': '2 of 3', 'leg_strikes': '7 of 9', 'distance_strikes': '12 of 34', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Kennedy Nzechukwu:
# Height: 6' 5"
# Reach: 83"
# Date of Birth: 1992-06-13 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/8667caa0451d245b
#
# Fighter Info for Chris Barnett:
# Height: 5' 9"
# Reach: 75"
# Date of Birth: 1986-06-14 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/7a5e8c94a86f9895
#
# Fight Summary for Farid Basharat vs Victor Hugo:
# Winner: Farid Basharat
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Featherweight Bout
# Referee: Kerry Hatley
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/5c783cd188425783
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Farid Basharat', 'knockdowns': '0', 'sig_strikes': '22 of 38', 'total_strikes': '27 of 50', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:42', 'head_strikes': '11 of 24', 'body_strikes': '2 of 4', 'leg_strikes': '9 of 10', 'distance_strikes': '20 of 33', 'clinch_strikes': '0 of 0', 'ground_strikes': '2 of 5'}
#
# Fighter B: {'name': 'Victor Hugo', 'knockdowns': '0', 'sig_strikes': '10 of 38', 'total_strikes': '11 of 39', 'takedowns': '0 of 3', 'sub_attempts': '1', 'reversals': '0', 'control_time': '0:04', 'head_strikes': '4 of 24', 'body_strikes': '3 of 8', 'leg_strikes': '3 of 6', 'distance_strikes': '10 of 38', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Farid Basharat', 'knockdowns': '0', 'sig_strikes': '30 of 71', 'total_strikes': '30 of 71', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:02', 'head_strikes': '22 of 59', 'body_strikes': '5 of 8', 'leg_strikes': '3 of 4', 'distance_strikes': '29 of 69', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Victor Hugo', 'knockdowns': '0', 'sig_strikes': '25 of 66', 'total_strikes': '25 of 66', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:14', 'head_strikes': '11 of 40', 'body_strikes': '9 of 17', 'leg_strikes': '5 of 9', 'distance_strikes': '25 of 66', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Farid Basharat', 'knockdowns': '0', 'sig_strikes': '8 of 17', 'total_strikes': '32 of 47', 'takedowns': '4 of 6', 'sub_attempts': '0', 'reversals': '0', 'control_time': '3:53', 'head_strikes': '6 of 15', 'body_strikes': '1 of 1', 'leg_strikes': '1 of 1', 'distance_strikes': '5 of 14', 'clinch_strikes': '1 of 1', 'ground_strikes': '2 of 2'}
#
# Fighter B: {'name': 'Victor Hugo', 'knockdowns': '0', 'sig_strikes': '10 of 21', 'total_strikes': '12 of 23', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '8 of 18', 'body_strikes': '2 of 3', 'leg_strikes': '0 of 0', 'distance_strikes': '8 of 18', 'clinch_strikes': '2 of 3', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Farid Basharat:
# Height: 5' 8"
# Reach: 71"
# Date of Birth: 1997-08-02 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/a09ed60aa67a3f67
#
# Fighter Info for Victor Hugo:
# Height: 5' 7"
# Reach: 71"
# Date of Birth: 1992-11-22 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/f264ba50b007f39e
#
# Fight Summary for Ismail Naurdiev vs Bruno Silva:
# Winner: Ismail Naurdiev
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Middleweight Bout
# Referee: Mark Smith
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/bde635a4f345bc3e
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Ismail Naurdiev', 'knockdowns': '0', 'sig_strikes': '13 of 27', 'total_strikes': '21 of 38', 'takedowns': '1 of 5', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:03', 'head_strikes': '6 of 18', 'body_strikes': '4 of 6', 'leg_strikes': '3 of 3', 'distance_strikes': '8 of 19', 'clinch_strikes': '5 of 8', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Bruno Silva', 'knockdowns': '0', 'sig_strikes': '12 of 27', 'total_strikes': '12 of 27', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '7 of 20', 'body_strikes': '2 of 3', 'leg_strikes': '3 of 4', 'distance_strikes': '10 of 23', 'clinch_strikes': '2 of 4', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Ismail Naurdiev', 'knockdowns': '0', 'sig_strikes': '20 of 39', 'total_strikes': '40 of 62', 'takedowns': '2 of 4', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:10', 'head_strikes': '15 of 31', 'body_strikes': '4 of 7', 'leg_strikes': '1 of 1', 'distance_strikes': '15 of 33', 'clinch_strikes': '1 of 2', 'ground_strikes': '4 of 4'}
#
# Fighter B: {'name': 'Bruno Silva', 'knockdowns': '0', 'sig_strikes': '14 of 33', 'total_strikes': '16 of 35', 'takedowns': '0 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '12 of 28', 'body_strikes': '1 of 2', 'leg_strikes': '1 of 3', 'distance_strikes': '12 of 29', 'clinch_strikes': '2 of 4', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Ismail Naurdiev', 'knockdowns': '0', 'sig_strikes': '33 of 50', 'total_strikes': '46 of 66', 'takedowns': '0 of 4', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:38', 'head_strikes': '21 of 38', 'body_strikes': '7 of 7', 'leg_strikes': '5 of 5', 'distance_strikes': '28 of 44', 'clinch_strikes': '5 of 6', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Bruno Silva', 'knockdowns': '0', 'sig_strikes': '10 of 37', 'total_strikes': '10 of 38', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '9 of 35', 'body_strikes': '1 of 1', 'leg_strikes': '0 of 1', 'distance_strikes': '8 of 33', 'clinch_strikes': '2 of 4', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Ismail Naurdiev:
# Height: 5' 10"
# Reach: 74"
# Date of Birth: 1996-08-18 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/6a96ad1bc34fb113
#
# Fighter Info for Bruno Silva:
# Height: 6' 0"
# Reach: 74"
# Date of Birth: 1989-07-13 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/12ebd7d157e91701
#
# Fight Summary for Rinat Fakhretdinov vs Carlos Leal:
# Winner: Rinat Fakhretdinov
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Welterweight Bout
# Referee: Vitor Ribeiro
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/6114076c689e8457
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Rinat Fakhretdinov', 'knockdowns': '0', 'sig_strikes': '24 of 53', 'total_strikes': '28 of 59', 'takedowns': '1 of 7', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:57', 'head_strikes': '17 of 43', 'body_strikes': '3 of 6', 'leg_strikes': '4 of 4', 'distance_strikes': '24 of 47', 'clinch_strikes': '0 of 6', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Carlos Leal', 'knockdowns': '0', 'sig_strikes': '28 of 63', 'total_strikes': '56 of 95', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '19 of 53', 'body_strikes': '5 of 6', 'leg_strikes': '4 of 4', 'distance_strikes': '24 of 59', 'clinch_strikes': '4 of 4', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Rinat Fakhretdinov', 'knockdowns': '0', 'sig_strikes': '33 of 68', 'total_strikes': '37 of 73', 'takedowns': '1 of 4', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:53', 'head_strikes': '24 of 56', 'body_strikes': '5 of 8', 'leg_strikes': '4 of 4', 'distance_strikes': '31 of 65', 'clinch_strikes': '2 of 3', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Carlos Leal', 'knockdowns': '0', 'sig_strikes': '37 of 86', 'total_strikes': '44 of 94', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '25 of 72', 'body_strikes': '3 of 5', 'leg_strikes': '9 of 9', 'distance_strikes': '35 of 83', 'clinch_strikes': '2 of 3', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Rinat Fakhretdinov', 'knockdowns': '0', 'sig_strikes': '52 of 101', 'total_strikes': '54 of 104', 'takedowns': '0 of 8', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:24', 'head_strikes': '41 of 85', 'body_strikes': '7 of 12', 'leg_strikes': '4 of 4', 'distance_strikes': '41 of 85', 'clinch_strikes': '11 of 16', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Carlos Leal', 'knockdowns': '0', 'sig_strikes': '42 of 97', 'total_strikes': '46 of 103', 'takedowns': '1 of 3', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:13', 'head_strikes': '28 of 82', 'body_strikes': '8 of 9', 'leg_strikes': '6 of 6', 'distance_strikes': '35 of 89', 'clinch_strikes': '7 of 8', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Rinat Fakhretdinov:
# Height: 6' 0"
# Reach: 74"
# Date of Birth: 1991-09-28 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/8f765fd5775a8873
#
# Fighter Info for Carlos Leal:
# Height: 5' 11"
# Reach: 74"
# Date of Birth: 1994-05-04 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/28d421729451c8ca
#
# Event: UFC Fight Night: Hernandez vs. Pereira
# Event Link: http://www.ufcstats.com/event-details/6a0047ac8c99fece
# Date: 2024-10-19 00:00:00
# Location: Las Vegas, Nevada, USA
#
# Fight Summary for Anthony Hernandez vs Michel Pereira:
# Winner: Anthony Hernandez
# Method of Victory: KO/TKO
# Round of Victory: 5
# Time of Victory: 2:22
# Time Format: 5 Rnd (5-5-5-5-5)
# Weight Class: Middleweight Bout
# Referee: Herb Dean
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/a2f2c64f9fb3fb1c
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Anthony Hernandez', 'knockdowns': '0', 'sig_strikes': '27 of 52', 'total_strikes': '30 of 55', 'takedowns': '1 of 8', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:25', 'head_strikes': '20 of 42', 'body_strikes': '5 of 7', 'leg_strikes': '2 of 3', 'distance_strikes': '17 of 40', 'clinch_strikes': '4 of 5', 'ground_strikes': '6 of 7'}
#
# Fighter B: {'name': 'Michel Pereira', 'knockdowns': '0', 'sig_strikes': '15 of 34', 'total_strikes': '17 of 36', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:19', 'head_strikes': '7 of 19', 'body_strikes': '8 of 15', 'leg_strikes': '0 of 0', 'distance_strikes': '12 of 28', 'clinch_strikes': '3 of 6', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Anthony Hernandez', 'knockdowns': '0', 'sig_strikes': '30 of 47', 'total_strikes': '47 of 68', 'takedowns': '2 of 6', 'sub_attempts': '0', 'reversals': '0', 'control_time': '3:18', 'head_strikes': '25 of 42', 'body_strikes': '4 of 4', 'leg_strikes': '1 of 1', 'distance_strikes': '9 of 15', 'clinch_strikes': '0 of 1', 'ground_strikes': '21 of 31'}
#
# Fighter B: {'name': 'Michel Pereira', 'knockdowns': '0', 'sig_strikes': '2 of 7', 'total_strikes': '2 of 7', 'takedowns': '0 of 0', 'sub_attempts': '1', 'reversals': '1', 'control_time': '0:35', 'head_strikes': '0 of 4', 'body_strikes': '2 of 3', 'leg_strikes': '0 of 0', 'distance_strikes': '2 of 7', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Anthony Hernandez', 'knockdowns': '0', 'sig_strikes': '44 of 55', 'total_strikes': '64 of 77', 'takedowns': '2 of 6', 'sub_attempts': '0', 'reversals': '0', 'control_time': '4:17', 'head_strikes': '31 of 42', 'body_strikes': '11 of 11', 'leg_strikes': '2 of 2', 'distance_strikes': '8 of 15', 'clinch_strikes': '4 of 4', 'ground_strikes': '32 of 36'}
#
# Fighter B: {'name': 'Michel Pereira', 'knockdowns': '0', 'sig_strikes': '3 of 8', 'total_strikes': '4 of 9', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '1 of 4', 'body_strikes': '2 of 4', 'leg_strikes': '0 of 0', 'distance_strikes': '2 of 6', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Round 4:
# Fighter A: {'name': 'Anthony Hernandez', 'knockdowns': '0', 'sig_strikes': '29 of 35', 'total_strikes': '48 of 62', 'takedowns': '3 of 6', 'sub_attempts': '0', 'reversals': '0', 'control_time': '4:35', 'head_strikes': '28 of 34', 'body_strikes': '1 of 1', 'leg_strikes': '0 of 0', 'distance_strikes': '5 of 6', 'clinch_strikes': '3 of 3', 'ground_strikes': '21 of 26'}
#
# Fighter B: {'name': 'Michel Pereira', 'knockdowns': '0', 'sig_strikes': '3 of 3', 'total_strikes': '5 of 9', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:02', 'head_strikes': '0 of 0', 'body_strikes': '3 of 3', 'leg_strikes': '0 of 0', 'distance_strikes': '3 of 3', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 5:
# Fighter A: {'name': 'Anthony Hernandez', 'knockdowns': '0', 'sig_strikes': '22 of 23', 'total_strikes': '30 of 31', 'takedowns': '2 of 3', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:07', 'head_strikes': '21 of 22', 'body_strikes': '1 of 1', 'leg_strikes': '0 of 0', 'distance_strikes': '4 of 5', 'clinch_strikes': '1 of 1', 'ground_strikes': '17 of 17'}
#
# Fighter B: {'name': 'Michel Pereira', 'knockdowns': '0', 'sig_strikes': '1 of 1', 'total_strikes': '1 of 1', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '0 of 0', 'body_strikes': '1 of 1', 'leg_strikes': '0 of 0', 'distance_strikes': '1 of 1', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Anthony Hernandez:
# Height: 6' 0"
# Reach: 75"
# Date of Birth: 1993-10-18 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/093e1f5bb73850be
#
# Fighter Info for Michel Pereira:
# Height: 6' 1"
# Reach: 73"
# Date of Birth: 1993-10-06 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/595db60957de51d3
#
# Fight Summary for Rob Font vs Kyler Phillips:
# Winner: Rob Font
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Bantamweight Bout
# Referee: Keith Peterson
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/f01b97e864cb4b8b
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Rob Font', 'knockdowns': '0', 'sig_strikes': '7 of 19', 'total_strikes': '7 of 20', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:29', 'head_strikes': '6 of 17', 'body_strikes': '1 of 2', 'leg_strikes': '0 of 0', 'distance_strikes': '6 of 18', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Kyler Phillips', 'knockdowns': '0', 'sig_strikes': '10 of 26', 'total_strikes': '21 of 42', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '3:34', 'head_strikes': '8 of 23', 'body_strikes': '2 of 2', 'leg_strikes': '0 of 1', 'distance_strikes': '5 of 19', 'clinch_strikes': '0 of 0', 'ground_strikes': '5 of 7'}
#
# Round 2:
# Fighter A: {'name': 'Rob Font', 'knockdowns': '0', 'sig_strikes': '31 of 58', 'total_strikes': '34 of 63', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:29', 'head_strikes': '23 of 48', 'body_strikes': '8 of 10', 'leg_strikes': '0 of 0', 'distance_strikes': '28 of 55', 'clinch_strikes': '3 of 3', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Kyler Phillips', 'knockdowns': '0', 'sig_strikes': '14 of 48', 'total_strikes': '15 of 49', 'takedowns': '2 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:24', 'head_strikes': '6 of 38', 'body_strikes': '5 of 6', 'leg_strikes': '3 of 4', 'distance_strikes': '13 of 44', 'clinch_strikes': '1 of 4', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Rob Font', 'knockdowns': '0', 'sig_strikes': '23 of 60', 'total_strikes': '24 of 61', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:21', 'head_strikes': '21 of 57', 'body_strikes': '2 of 3', 'leg_strikes': '0 of 0', 'distance_strikes': '22 of 58', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Kyler Phillips', 'knockdowns': '0', 'sig_strikes': '14 of 51', 'total_strikes': '14 of 52', 'takedowns': '1 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:44', 'head_strikes': '5 of 37', 'body_strikes': '2 of 6', 'leg_strikes': '7 of 8', 'distance_strikes': '14 of 49', 'clinch_strikes': '0 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Rob Font:
# Height: 5' 8"
# Reach: 71"
# Date of Birth: 1987-06-25 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/05339613bf8e9808
#
# Fighter Info for Kyler Phillips:
# Height: 5' 8"
# Reach: 72"
# Date of Birth: 1995-06-12 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/60425d07ef4b91a7
#
# Fight Summary for Charles Johnson vs Sumudaerji:
# Winner: Charles Johnson
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Flyweight Bout
# Referee: Mark Smith
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/503d7342cc08109f
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Charles Johnson', 'knockdowns': '0', 'sig_strikes': '19 of 50', 'total_strikes': '33 of 64', 'takedowns': '0 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:16', 'head_strikes': '12 of 42', 'body_strikes': '5 of 5', 'leg_strikes': '2 of 3', 'distance_strikes': '16 of 44', 'clinch_strikes': '3 of 6', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Sumudaerji', 'knockdowns': '0', 'sig_strikes': '24 of 43', 'total_strikes': '24 of 43', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:03', 'head_strikes': '12 of 26', 'body_strikes': '2 of 3', 'leg_strikes': '10 of 14', 'distance_strikes': '20 of 39', 'clinch_strikes': '4 of 4', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Charles Johnson', 'knockdowns': '1', 'sig_strikes': '30 of 60', 'total_strikes': '34 of 72', 'takedowns': '1 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:03', 'head_strikes': '20 of 41', 'body_strikes': '5 of 11', 'leg_strikes': '5 of 8', 'distance_strikes': '19 of 43', 'clinch_strikes': '0 of 0', 'ground_strikes': '11 of 17'}
#
# Fighter B: {'name': 'Sumudaerji', 'knockdowns': '0', 'sig_strikes': '23 of 44', 'total_strikes': '25 of 48', 'takedowns': '0 of 0', 'sub_attempts': '2', 'reversals': '1', 'control_time': '0:30', 'head_strikes': '15 of 32', 'body_strikes': '2 of 5', 'leg_strikes': '6 of 7', 'distance_strikes': '22 of 42', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Charles Johnson', 'knockdowns': '0', 'sig_strikes': '16 of 40', 'total_strikes': '17 of 41', 'takedowns': '1 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:39', 'head_strikes': '10 of 30', 'body_strikes': '5 of 6', 'leg_strikes': '1 of 4', 'distance_strikes': '14 of 36', 'clinch_strikes': '2 of 4', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Sumudaerji', 'knockdowns': '0', 'sig_strikes': '28 of 57', 'total_strikes': '29 of 58', 'takedowns': '0 of 3', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:17', 'head_strikes': '14 of 38', 'body_strikes': '3 of 7', 'leg_strikes': '11 of 12', 'distance_strikes': '26 of 54', 'clinch_strikes': '2 of 3', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Charles Johnson:
# Height: 5' 9"
# Reach: 70"
# Date of Birth: 1991-01-10 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/814e5233e2acf2ee
#
# Fighter Info for Sumudaerji:
# Height: 5' 8"
# Reach: 72"
# Date of Birth: 1996-01-20 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/3cf18e01cb6cbde3
#
# Fight Summary for Cameron Smotherman vs Jake Hadley:
# Winner: Cameron Smotherman
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Bantamweight Bout
# Referee: Chris Tognoni
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/a2f46e94aa6b0c64
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Cameron Smotherman', 'knockdowns': '0', 'sig_strikes': '37 of 79', 'total_strikes': '37 of 79', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '13 of 48', 'body_strikes': '23 of 30', 'leg_strikes': '1 of 1', 'distance_strikes': '37 of 79', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Jake Hadley', 'knockdowns': '0', 'sig_strikes': '24 of 58', 'total_strikes': '24 of 58', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '8 of 40', 'body_strikes': '7 of 7', 'leg_strikes': '9 of 11', 'distance_strikes': '24 of 58', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Cameron Smotherman', 'knockdowns': '0', 'sig_strikes': '25 of 75', 'total_strikes': '26 of 76', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '13 of 52', 'body_strikes': '10 of 21', 'leg_strikes': '2 of 2', 'distance_strikes': '25 of 75', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Jake Hadley', 'knockdowns': '0', 'sig_strikes': '18 of 57', 'total_strikes': '27 of 67', 'takedowns': '1 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:07', 'head_strikes': '6 of 40', 'body_strikes': '7 of 12', 'leg_strikes': '5 of 5', 'distance_strikes': '17 of 56', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Cameron Smotherman', 'knockdowns': '0', 'sig_strikes': '34 of 105', 'total_strikes': '34 of 105', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '17 of 81', 'body_strikes': '15 of 21', 'leg_strikes': '2 of 3', 'distance_strikes': '34 of 105', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Jake Hadley', 'knockdowns': '0', 'sig_strikes': '18 of 50', 'total_strikes': '19 of 51', 'takedowns': '0 of 1', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:46', 'head_strikes': '14 of 44', 'body_strikes': '3 of 5', 'leg_strikes': '1 of 1', 'distance_strikes': '18 of 49', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Cameron Smotherman:
# Height: 5' 9"
# Reach: 69"
# Date of Birth: 1997-09-17 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/5c84f673b7bb7c15
#
# Fighter Info for Jake Hadley:
# Height: 5' 7"
# Reach: 70"
# Date of Birth: 1996-08-03 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/60a42bf82447c919
#
# Fight Summary for Darren Elkins vs Daniel Pineda:
# Winner: Darren Elkins
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Featherweight Bout
# Referee: Herb Dean
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/0599f35e6679de02
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Darren Elkins', 'knockdowns': '0', 'sig_strikes': '3 of 8', 'total_strikes': '23 of 35', 'takedowns': '1 of 2', 'sub_attempts': '0', 'reversals': '1', 'control_time': '2:07', 'head_strikes': '3 of 8', 'body_strikes': '0 of 0', 'leg_strikes': '0 of 0', 'distance_strikes': '2 of 6', 'clinch_strikes': '0 of 1', 'ground_strikes': '1 of 1'}
#
# Fighter B: {'name': 'Daniel Pineda', 'knockdowns': '0', 'sig_strikes': '13 of 15', 'total_strikes': '27 of 30', 'takedowns': '0 of 0', 'sub_attempts': '2', 'reversals': '1', 'control_time': '2:07', 'head_strikes': '12 of 13', 'body_strikes': '1 of 2', 'leg_strikes': '0 of 0', 'distance_strikes': '1 of 2', 'clinch_strikes': '0 of 0', 'ground_strikes': '12 of 13'}
#
# Round 2:
# Fighter A: {'name': 'Darren Elkins', 'knockdowns': '0', 'sig_strikes': '19 of 47', 'total_strikes': '39 of 72', 'takedowns': '2 of 4', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:24', 'head_strikes': '15 of 42', 'body_strikes': '4 of 5', 'leg_strikes': '0 of 0', 'distance_strikes': '12 of 37', 'clinch_strikes': '0 of 0', 'ground_strikes': '7 of 10'}
#
# Fighter B: {'name': 'Daniel Pineda', 'knockdowns': '0', 'sig_strikes': '12 of 24', 'total_strikes': '17 of 29', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:05', 'head_strikes': '6 of 15', 'body_strikes': '5 of 6', 'leg_strikes': '1 of 3', 'distance_strikes': '10 of 22', 'clinch_strikes': '1 of 1', 'ground_strikes': '1 of 1'}
#
# Round 3:
# Fighter A: {'name': 'Darren Elkins', 'knockdowns': '0', 'sig_strikes': '17 of 33', 'total_strikes': '40 of 63', 'takedowns': '0 of 6', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:02', 'head_strikes': '12 of 28', 'body_strikes': '5 of 5', 'leg_strikes': '0 of 0', 'distance_strikes': '14 of 27', 'clinch_strikes': '3 of 6', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Daniel Pineda', 'knockdowns': '0', 'sig_strikes': '6 of 14', 'total_strikes': '17 of 26', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:50', 'head_strikes': '3 of 10', 'body_strikes': '1 of 2', 'leg_strikes': '2 of 2', 'distance_strikes': '6 of 13', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 1'}
#
# Fighter Info for Darren Elkins:
# Height: 5' 10"
# Reach: 71"
# Date of Birth: 1984-05-16 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/92a9aa9c93192871
#
# Fighter Info for Daniel Pineda:
# Height: 5' 7"
# Reach: 69"
# Date of Birth: 1985-08-06 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/361d49960a196976
#
# Fight Summary for Asu Almabayev vs Matheus Nicolau:
# Winner: Asu Almabayev
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Flyweight Bout
# Referee: Keith Peterson
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/c61923255389e67c
#
# Rounds Information:
#
# Round 1:
# ...
#
# Round 4:
# Fighter A: {'name': 'Umar Nurmagomedov', 'knockdowns': '0', 'sig_strikes': '30 of 65', 'total_strikes': '32 of 67', 'takedowns': '1 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:36', 'head_strikes': '21 of 55', 'body_strikes': '5 of 6', 'leg_strikes': '4 of 4', 'distance_strikes': '29 of 63', 'clinch_strikes': '1 of 2', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Cory Sandhagen', 'knockdowns': '0', 'sig_strikes': '20 of 53', 'total_strikes': '20 of 53', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '11 of 43', 'body_strikes': '7 of 8', 'leg_strikes': '2 of 2', 'distance_strikes': '20 of 53', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Round 5:
# Fighter A: {'name': 'Umar Nurmagomedov', 'knockdowns': '0', 'sig_strikes': '12 of 25', 'total_strikes': '32 of 52', 'takedowns': '1 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:36', 'head_strikes': '6 of 18', 'body_strikes': '5 of 6', 'leg_strikes': '1 of 1', 'distance_strikes': '12 of 25', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Cory Sandhagen', 'knockdowns': '0', 'sig_strikes': '6 of 10', 'total_strikes': '11 of 17', 'takedowns': '0 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '3 of 6', 'body_strikes': '1 of 1', 'leg_strikes': '2 of 3', 'distance_strikes': '6 of 9', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Umar Nurmagomedov:
# Height: 5' 8"
# Reach: 69"
# Date of Birth: 1996-01-03 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/2b6fc1c02736833d
#
# Fighter Info for Cory Sandhagen:
# Height: 5' 11"
# Reach: 70"
# Date of Birth: 1992-04-20 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/65f09bacd3957381
#
# Fight Summary for Shara Magomedov vs Michal Oleksiejczuk:
# Winner: Shara Magomedov
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Middleweight Bout
# Referee: Daniel Movahedi
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/b38450d9aa0f52b8
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Shara Magomedov', 'knockdowns': '0', 'sig_strikes': '40 of 74', 'total_strikes': '42 of 76', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '16 of 39', 'body_strikes': '17 of 26', 'leg_strikes': '7 of 9', 'distance_strikes': '38 of 69', 'clinch_strikes': '2 of 5', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Michal Oleksiejczuk', 'knockdowns': '0', 'sig_strikes': '35 of 53', 'total_strikes': '36 of 54', 'takedowns': '0 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:08', 'head_strikes': '23 of 38', 'body_strikes': '9 of 11', 'leg_strikes': '3 of 4', 'distance_strikes': '34 of 50', 'clinch_strikes': '1 of 3', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Shara Magomedov', 'knockdowns': '0', 'sig_strikes': '35 of 64', 'total_strikes': '37 of 67', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '24 of 48', 'body_strikes': '7 of 12', 'leg_strikes': '4 of 4', 'distance_strikes': '33 of 60', 'clinch_strikes': '2 of 4', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Michal Oleksiejczuk', 'knockdowns': '0', 'sig_strikes': '24 of 52', 'total_strikes': '28 of 58', 'takedowns': '1 of 2', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:44', 'head_strikes': '12 of 35', 'body_strikes': '5 of 9', 'leg_strikes': '7 of 8', 'distance_strikes': '22 of 50', 'clinch_strikes': '2 of 2', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Shara Magomedov', 'knockdowns': '0', 'sig_strikes': '22 of 40', 'total_strikes': '44 of 66', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '12 of 25', 'body_strikes': '9 of 14', 'leg_strikes': '1 of 1', 'distance_strikes': '18 of 34', 'clinch_strikes': '4 of 6', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Michal Oleksiejczuk', 'knockdowns': '0', 'sig_strikes': '18 of 41', 'total_strikes': '30 of 60', 'takedowns': '2 of 3', 'sub_attempts': '0', 'reversals': '0', 'control_time': '1:47', 'head_strikes': '10 of 30', 'body_strikes': '4 of 7', 'leg_strikes': '4 of 4', 'distance_strikes': '16 of 38', 'clinch_strikes': '1 of 1', 'ground_strikes': '1 of 2'}
#
# Fighter Info for Shara Magomedov:
# Height: 6' 2"
# Reach: 73"
# Date of Birth: 1994-05-16 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/06734ca9d88dec3a
#
# Fighter Info for Michal Oleksiejczuk:
# Height: 6' 0"
# Reach: 74"
# Date of Birth: 1995-02-22 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/0d65c432720accb9
#
# Fight Summary for Deiveson Figueiredo vs Marlon Vera:
# Winner: Deiveson Figueiredo
# Method of Victory: Decision - Unanimous
# Round of Victory: 3
# Time of Victory: 5:00
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Bantamweight Bout
# Referee: Keith Peterson
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/bb85e207eba236bc
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Deiveson Figueiredo', 'knockdowns': '0', 'sig_strikes': '10 of 12', 'total_strikes': '22 of 24', 'takedowns': '2 of 3', 'sub_attempts': '0', 'reversals': '0', 'control_time': '2:20', 'head_strikes': '3 of 5', 'body_strikes': '2 of 2', 'leg_strikes': '5 of 5', 'distance_strikes': '8 of 9', 'clinch_strikes': '0 of 0', 'ground_strikes': '2 of 3'}
#
# Fighter B: {'name': 'Marlon Vera', 'knockdowns': '0', 'sig_strikes': '8 of 18', 'total_strikes': '21 of 35', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '2 of 10', 'body_strikes': '1 of 1', 'leg_strikes': '5 of 7', 'distance_strikes': '6 of 14', 'clinch_strikes': '2 of 4', 'ground_strikes': '0 of 0'}
#
# Round 2:
# Fighter A: {'name': 'Deiveson Figueiredo', 'knockdowns': '0', 'sig_strikes': '14 of 28', 'total_strikes': '14 of 28', 'takedowns': '0 of 6', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '4 of 15', 'body_strikes': '5 of 7', 'leg_strikes': '5 of 6', 'distance_strikes': '13 of 27', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Marlon Vera', 'knockdowns': '0', 'sig_strikes': '18 of 40', 'total_strikes': '19 of 41', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:05', 'head_strikes': '1 of 17', 'body_strikes': '5 of 9', 'leg_strikes': '12 of 14', 'distance_strikes': '17 of 39', 'clinch_strikes': '1 of 1', 'ground_strikes': '0 of 0'}
#
# Round 3:
# Fighter A: {'name': 'Deiveson Figueiredo', 'knockdowns': '1', 'sig_strikes': '21 of 50', 'total_strikes': '23 of 52', 'takedowns': '0 of 5', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:10', 'head_strikes': '11 of 37', 'body_strikes': '8 of 11', 'leg_strikes': '2 of 2', 'distance_strikes': '21 of 48', 'clinch_strikes': '0 of 1', 'ground_strikes': '0 of 1'}
#
# Fighter B: {'name': 'Marlon Vera', 'knockdowns': '0', 'sig_strikes': '26 of 59', 'total_strikes': '27 of 60', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:03', 'head_strikes': '12 of 40', 'body_strikes': '9 of 12', 'leg_strikes': '5 of 7', 'distance_strikes': '23 of 55', 'clinch_strikes': '3 of 4', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Deiveson Figueiredo:
# Height: 5' 5"
# Reach: 68"
# Date of Birth: 1987-12-18 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/aa72b0f831d0bfe5
#
# Fighter Info for Marlon Vera:
# Height: 5' 8"
# Reach: 70"
# Date of Birth: 1992-12-02 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/7c7332319c14094c
#
# Fight Summary for Michael Chiesa vs Tony Ferguson:
# Winner: Michael Chiesa
# Method of Victory: Submission
# Round of Victory: 1
# Time of Victory: 3:44
# Time Format: 3 Rnd (5-5-5)
# Weight Class: Welterweight Bout
# Referee: Marc Goddard
# Title Fight: False
# Gender: men
# Fight Link: http://www.ufcstats.com/fight-details/2d39c26876246223
#
# Rounds Information:
#
# Round 1:
# Fighter A: {'name': 'Michael Chiesa', 'knockdowns': '0', 'sig_strikes': '4 of 25', 'total_strikes': '4 of 25', 'takedowns': '1 of 1', 'sub_attempts': '1', 'reversals': '0', 'control_time': '0:34', 'head_strikes': '3 of 23', 'body_strikes': '1 of 2', 'leg_strikes': '0 of 0', 'distance_strikes': '4 of 25', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter B: {'name': 'Tony Ferguson', 'knockdowns': '0', 'sig_strikes': '10 of 18', 'total_strikes': '10 of 18', 'takedowns': '0 of 0', 'sub_attempts': '0', 'reversals': '0', 'control_time': '0:00', 'head_strikes': '4 of 9', 'body_strikes': '1 of 3', 'leg_strikes': '5 of 6', 'distance_strikes': '10 of 18', 'clinch_strikes': '0 of 0', 'ground_strikes': '0 of 0'}
#
# Fighter Info for Michael Chiesa:
# Height: 6' 1"
# Reach: 75"
# Date of Birth: 1987-12-07 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/c58f51dedb310998
#
# Fighter Info for Tony Ferguson:
# Height: 5' 11"
# Reach: 76"
# Date of Birth: 1984-02-12 00:00:00
# Fighter Link: http://www.ufcstats.com/fighter-details/22a92d7f62195791
# Saving data to CSV due to an error or normal completion.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 575, in main()
#     574 for fight_info in event_info['fights']:
# --> 575     scrape_fight_info(fight_info)
#     576     scrape_fighter_info(fight_info['fighter_a'])
#
# Cell In[2], line 179, in scrape_fight_info(fight_info)
#     178 fight_url = fight_info['fight_link']
# --> 179 fight_soup = get_page_content(fight_url)
#     181 if not fight_soup:
#
# Cell In[2], line 26, in get_page_content(url)
#      25 try:
# ---> 26     response = requests.get(url, headers=headers)
#      27     if response.status_code == 200:
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     460 try:
# --> 461     httplib_response = conn.getresponse()
#     462 except BaseException as e:
#     463     # Remove the TypeError from the exception chain in
#     464     # Python 3 (including for exceptions like SystemExit).
#     465     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\Lib\http\client.py:1378, in HTTPConnection.getresponse(self)
#    1377 try:
# -> 1378     response.begin()
#    1379 except ConnectionError:
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     705 try:
# --> 706     return self._sock.recv_into(b)
#     707 except timeout:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 593
#     588             write_to_csv(events_list)
#     591 if __name__ == "__main__":
#     592     # Script entry point, calls the main function to start the process
# --> 593     events_list = main()
#     594     write_to_csv(events_list)
#
# Cell In[2], line 588, in main()
#     586 if events_list:
#     587     print("Saving data to CSV due to an error or normal completion.")
# --> 588     write_to_csv(events_list)
#
# Cell In[2], line 497, in write_to_csv(events_list)
#     492 for event in events_list:
#     493     for fight in event['fights']:
#     494         row = [
#     495             event['name'], event['date'], event['location'], fight['winner'],
#     496             fight['fighter_a']['name'], fight['fighter_b']['name'],
# --> 497             fight['weight_class'], fight['method_of_victory'],
#     498             fight['round_of_victory'], fight['time_in_ROV'], fight['time_format'],
#     499             fight['referee'], fight['title_fight'], fight['gender'],
#     500             fight['fight_link'], fight['fighter_a'].get('height', {}).get('inches', 'NaN'),
#     501             fight['fighter_a'].get('reach', 'NaN'), fight['fighter_a'].get('dob', 'NaN'),
#     502             fight['fighter_b'].get('height', {}).get('inches', 'NaN'),
#     503             fight['fighter_b'].get('reach', 'NaN'),
#     504             fight['fighter_b'].get('dob', 'NaN')
#     505         ]
#     507         # Adding round details for each fighter
#     508         for round_num in range(1, rounds + 1):
#
# KeyError: 'weight_class'
